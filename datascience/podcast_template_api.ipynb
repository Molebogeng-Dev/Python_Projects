# %%
from podcast_templet import Templet

api_data=Templet().update_all

# %%
print(api_data)
# Out:
#                Title             Guest        Main_topic
# Number1   First test              Lebo  File manipulator
# Number2  Second test             Amour             Music
# Number3   Third test        Molebogeng            Coding
# Number4        Final  Morwa Production           Podcast
