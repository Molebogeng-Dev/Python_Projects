# %%
import pandas as pd

episodes=[{"Title": ":______", "Guest": ":___", "Main_topic": ":__________"},
          {"Title": ":______", "Guest": ":___", "Main_topic": ":__________"},
          {"Title": ":______", "Guest": ":___", "Main_topic": ":__________"},
          {"Title": ":______", "Guest": ":___", "Main_topic": ":__________"}]

# %%
index_name=[f"Number{i+1}" for i in range(len(episodes)) ]

# %%
df = pd.DataFrame(episodes, index= index_name)

# %%
print(df)
# Out:
#                 Title  Guest  Main_topic
# Number1  1:__________  1:___  __________
# Number2  2:__________  2:___  __________
# Number3  3:__________  3:___  __________
# Number4  4:__________  4:___  __________
